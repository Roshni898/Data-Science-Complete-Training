# %%
#Mode
#write
#new file write/create

# %%
f=open('day_4.txt',mode ='w')
f.write('This is Day 4 of DS training!!')
f.close()
print('Done')
# Out:
# Done

# %%
#pip install googlesearch-python
# Out:
# Collecting googlesearch-pythonNote: you may need to restart the kernel to use updated packages.
#
#   Downloading googlesearch_python-1.3.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: beautifulsoup4>=4.9 in c:\users\user\onedrive\documents\himanshu\lib\site-packages (from googlesearch-python) (4.12.3)
# Requirement already satisfied: requests>=2.20 in c:\users\user\onedrive\documents\himanshu\lib\site-packages (from googlesearch-python) (2.32.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\onedrive\documents\himanshu\lib\site-packages (from beautifulsoup4>=4.9->googlesearch-python) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\onedrive\documents\himanshu\lib\site-packages (from requests>=2.20->googlesearch-python) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\onedrive\documents\himanshu\lib\site-packages (from requests>=2.20->googlesearch-python) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\onedrive\documents\himanshu\lib\site-packages (from requests>=2.20->googlesearch-python) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\onedrive\documents\himanshu\lib\site-packages (from requests>=2.20->googlesearch-python) (2025.4.26)
# Downloading googlesearch_python-1.3.0-py3-none-any.whl (5.6 kB)
# Installing collected packages: googlesearch-python
# Successfully installed googlesearch-python-1.3.0
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from googlesearch import search
search('Data Science',num_results=10)
# Out:
# <generator object search at 0x0000016C925536A0>

# %%
from googlesearch import search
title='Free Python Complete Tutorial PDF'
data=search(title,num_results=10)
all_data=[]
for i in data:
    all_data.append(i+'\n')
file=open(f'{title}.txt',mode='w')
file.writelines(all_data)
f.close()
print('Done')
# Out:
# Done

# %%
from googlesearch import search
title='Java Tutorial PDF'
data=search(title,num_results=10)
all_data=[]
for i in data:
    all_data.append(i+'\n')
#Mode x:it only create new file
file=open(f'{title}.txt',mode='x')
file.writelines(all_data)
f.close()
print('Done')
# Out:
# Done

# %%
from googlesearch import search
title='Chat GPT Trending News and Investments'
data=search(title,num_results=5)
all_data=[]
for i in data:
    all_data.append(i+'\n')
#Mode a:it will  append new line
file=open(f'{title}.txt',mode='a')
file.write('========================\n')
file.writelines(all_data)
f.close()
print('Done')
# Out:
# Done

# %%
f=open('new.txt','w')
print(f.read())
f.close()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[30], line 2
#       1 f=open('new.txt','w')
# ----> 2 print(f.read())
#       3 f.close()
#
# UnsupportedOperation: not readable

# %%
f=open('day_4.txt','r')
print(f.write('This is a Python file'))
f.close()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[32], line 2
#       1 f=open('day_4.txt','r')
# ----> 2 print(f.write('This is a Python file'))
#       3 f.close()
#
# UnsupportedOperation: not writable

# %%
f=open('day_4.txt','r+')
print(f.read())
f.write('\nThis is again a New Line!!')
f.close()
# Out:
# This is Day 4 of DS training!!This is a New Line!!

# %%
#mode=w+
f=open('day_4.txt','w+')
print(f.read())
f.write('This is again a New Line!!')
f.seek(0)     #sending the cursor at the starting point then it will read
print(f.read())       #answer nhi ayega
f.close()
print('Done')
# Out:
# This is again a New Line!!
# Done

# %%
#mode=a+ (append and read)
#mode=x+ (new file write and uska read)
#r,w,r+,w+
#t = dekhne ke liye

# %%
f1=open('day_4.txt','r')
all_data = f1.read()
f2=open('day_4_copy.txt','w')
f2.write(all_data)
f1.close()
f2.close()
print('Done')
# Out:
# Done

# %% [markdown]
# # Binary File Handling

# %% [markdown]
# # Binary file Data= Bytes Format
# # copy data from binary file and create a new one

# %%
path = r'''C:\Users\user\OneDrive\Documents\excelp1.jpg''' #r=treat this as a raw string
file = open(path,mode = 'rb')
data=file.read()
print('Done')
# Out:
# Done

# %%
type(data)
# Out:
# bytes

# %%
file
# Out:
# <_io.BufferedReader name='C:\\Users\\user\\OneDrive\\Documents\\excelp1.jpg'>

# %%
print(data[:200])
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\x06\x06\x06\x06\x07\x06\x07\x08\x08\x07\n\x0b\n\x0b\n\x0f\x0e\x0c\x0c\x0e\x0f\x16\x10\x11\x10\x11\x10\x16"\x15\x19\x15\x15\x19\x15"\x1e$\x1e\x1c\x1e$\x1e6*&&*6>424>LDDL_Z_||\xa7\x01\x06\x06\x06\x06\x07\x06\x07\x08\x08\x07\n\x0b\n\x0b\n\x0f\x0e\x0c\x0c\x0e\x0f\x16\x10\x11\x10\x11\x10\x16"\x15\x19\x15\x15\x19\x15"\x1e$\x1e\x1c\x1e$\x1e6*&&*6>424>LDDL_Z_||\xa7\xff\xc2\x00\x11\x08\x03`\x04\x80\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x000\x00\x00\x03\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05'

# %%
f=open('image.jpg',mode='wb')
f.write(data)
f.close()
print('Done')
# Out:
# Done

# %%
#pip install qrcode
# Out:
# Collecting qrcode
#   Downloading qrcode-8.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: colorama in c:\users\user\onedrive\documents\himanshu\lib\site-packages (from qrcode) (0.4.6)
# Downloading qrcode-8.2-py3-none-any.whl (45 kB)
# Installing collected packages: qrcode
# Successfully installed qrcode-8.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
url='''https://github.com/Roshni898/Data-Science-Complete-Training/tree/main'''
import qrcode
img=qrcode.make(url)
img.save('gitqr.png')

# %%
url='''https://kittenswhiskers.com/wp-content/uploads/sites/23/2014/09/little-puss-in-boots.jpg'''
import requests as r
image_data=r.get(url).content #content - to show data in binary
type(image_data)
# Out:
# bytes

# %%
f=open('download_image.jpg','wb')
f.write(image_data)
f.close()

from IPython import display
display.Image('download_image.jpg')

# %%
url = '''https://picsum.photos/1080/720'''
import requests as r
n =10
for i in range(n):
    img_data= r.get(url).content
    f=open(f'image_{i}.jpg','wb')
    f.write(img_data)
    f.close()
    from IPython import display as d
    display(d.Image(f'image_{i}.jpg',width=200,height=200))

# %%
file_path='''https://www.python.org/ftp/python/3.13.5/python-3.13.5-amd64.exe'''
import requests as r
with open(r'C:\Users\user\OneDrive\Desktop\Data Science\Roshni.exe','wb') as file:
    file.write(r.get(file_path).content)
print('Done')
# Out:
# Done
